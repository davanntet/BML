# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
X = np.arange(20)
Y = 4*X +3*X**2 -100
plt.plot(X,Y)

# %%
model = LinearRegression()
model.fit(X[:,np.newaxis],Y)
y_predict = model.predict(X[:,np.newaxis])
plt.scatter(X,Y,c='blue')
plt.plot(X,y_predict,'r')

# %%
model = LinearRegression()
poly_processing = PolynomialFeatures(degree=2,include_bias=True)
x_poly2 = poly_processing.fit_transform(X[:,np.newaxis])
model.fit(x_poly2,Y)
y_predict = model.predict(x_poly2)
plt.scatter(X,Y,c='blue')
plt.plot(X,y_predict)

# %%
model.coef_
# Out:
# array([0., 4., 3.])

# %%
x_poly2
# Out:
# array([[  1.,   0.,   0.],
#        [  1.,   1.,   1.],
#        [  1.,   2.,   4.],
#        [  1.,   3.,   9.],
#        [  1.,   4.,  16.],
#        [  1.,   5.,  25.],
#        [  1.,   6.,  36.],
#        [  1.,   7.,  49.],
#        [  1.,   8.,  64.],
#        [  1.,   9.,  81.],
#        [  1.,  10., 100.],
#        [  1.,  11., 121.],
#        [  1.,  12., 144.],
#        [  1.,  13., 169.],
#        [  1.,  14., 196.],
#        [  1.,  15., 225.],
#        [  1.,  16., 256.],
#        [  1.,  17., 289.],
#        [  1.,  18., 324.],
#        [  1.,  19., 361.]])
